# %%
import pandas as pd

# %%
CSV_FILE_PATH = "./data/Electric_Vehicle_Population_Data.csv"
df = pd.read_csv(CSV_FILE_PATH)

# %% [markdown]
# First few rows of the data

# %%
df.head()
# Out:
#    VIN (1-10)     County       City State  Postal Code  Model Year   Make  \
# 0  5YJ3E1EB4L     Yakima     Yakima    WA        98908        2020  TESLA
# 1  5YJ3E1EA7K  San Diego  San Diego    CA        92101        2019  TESLA
# 2  7JRBR0FL9M       Lane     Eugene    OR        97404        2021  VOLVO
# 3  5YJXCBE21K     Yakima     Yakima    WA        98908        2019  TESLA
# 4  5UXKT0C5XH  Snohomish    Bothell    WA        98021        2017    BMW
#
#      Model                   Electric Vehicle Type  \
# 0  MODEL 3          Battery Electric Vehicle (BEV)
# 1  MODEL 3          Battery Electric Vehicle (BEV)
# 2      S60  Plug-in Hybrid Electric Vehicle (PHEV)
# 3  MODEL X          Battery Electric Vehicle (BEV)
# 4       X5  Plug-in Hybrid Electric Vehicle (PHEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible             322
# 1           Clean Alternative Fuel Vehicle Eligible             220
# ...

# %% [markdown]
# Summary statistics for numerical columns

# %%
df.describe()
# Out:
#         Postal Code    Model Year  Electric Range      Base MSRP  \
# count  75215.000000  75215.000000    75215.000000   75215.000000
# mean   98163.616646   2019.400332       79.460427    1598.116666
# std     2506.793636      2.973578      100.167882   10314.556810
# min     1730.000000   1999.000000        0.000000       0.000000
# 25%    98052.000000   2018.000000        0.000000       0.000000
# 50%    98118.000000   2020.000000       25.000000       0.000000
# 75%    98367.000000   2022.000000      200.000000       0.000000
# max    99701.000000   2023.000000      337.000000  845000.000000
#
#        Legislative District  DOL Vehicle ID  2020 Census Tract
# count          75051.000000    7.521500e+04       7.521500e+04
# mean              29.944424    2.042152e+08       5.297235e+10
# std               14.760174    8.914236e+07       1.650854e+09
# min                1.000000    4.777000e+03       2.090001e+09
# 25%               18.000000    1.540551e+08       5.303301e+10
# ...

# %% [markdown]
# Data types of each column

# %%
df.dtypes
# Out:
# VIN (1-10)                                            object
# County                                                object
# City                                                  object
# State                                                 object
# Postal Code                                            int64
# Model Year                                             int64
# Make                                                  object
# Model                                                 object
# Electric Vehicle Type                                 object
# Clean Alternative Fuel Vehicle (CAFV) Eligibility     object
# Electric Range                                         int64
# Base MSRP                                              int64
# Legislative District                                 float64
# DOL Vehicle ID                                         int64
# Vehicle Location                                      object
# ...

# %% [markdown]
# Missing values in each column

# %%
df.isnull().sum()
# Out:
# VIN (1-10)                                             0
# County                                                 0
# City                                                   0
# State                                                  0
# Postal Code                                            0
# Model Year                                             0
# Make                                                   0
# Model                                                109
# Electric Vehicle Type                                  0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility      0
# Electric Range                                         0
# Base MSRP                                              0
# Legislative District                                 164
# DOL Vehicle ID                                         0
# Vehicle Location                                      19
# Electric Utility                                     256
# ...

# %% [markdown]
# Total number of rows

# %%
len(df)
# Out:
# 75215

# %% [markdown]
# Unique values in each column

# %%
unique_counts = {col: df[col].nunique() for col in df.columns}
unique_counts
# Out:
# {'VIN (1-10)': 7476,
#  'County': 119,
#  'City': 540,
#  'State': 35,
#  'Postal Code': 646,
#  'Model Year': 17,
#  'Make': 35,
#  'Model': 119,
#  'Electric Vehicle Type': 2,
#  'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 3,
#  'Electric Range': 98,
#  'Base MSRP': 31,
#  'Legislative District': 49,
#  'DOL Vehicle ID': 75215,
#  'Vehicle Location': 639,
#  'Electric Utility': 72,
#  '2020 Census Tract': 1906}

# %% [markdown]
# Value counts for each column (top 5 values per column)

# %%
value_counts = {col: df[col].value_counts().head() for col in df.columns}
value_counts
# Out:
# {'VIN (1-10)': VIN (1-10)
#  5YJYGDEE0M    299
#  5YJYGDEE7M    288
#  5YJYGDEE9M    276
#  5YJYGDEE8M    275
#  5YJYGDEE2M    270
#  Name: count, dtype: int64,
#  'County': County
#  King         40531
#  Snohomish     8230
#  Pierce        5355
#  Clark         4645
#  Thurston      2808
#  Name: count, dtype: int64,
#  'City': City
#  Seattle      13714
#  Bellevue      4026
#  Redmond       2848
#  Vancouver     2841
#  Kirkland      2522
#  Name: count, dtype: int64,
#  'State': State
#  WA    75051
#  CA       52
#  VA       22
#  TX       10
#  MD        9
#  Name: count, dtype: int64,
#  'Postal Code': Postal Code
#  98052    2048
#  98033    1436
#  98012    1330
#  98004    1299
#  98006    1276
#  Name: count, dtype: int64,
#  'Model Year': Model Year
#  2022    16343
#  2021    11121
#  2018     8614
#  2023     8116
#  2020     6615
#  Name: count, dtype: int64,
#  'Make': Make
#  TESLA        34212
#  NISSAN        7983
#  CHEVROLET     6553
#  FORD          4025
# ...

# %% [markdown]
# Columns with mostly unique values (likely IDs)

# %%
unique_columns = df.nunique()[df.nunique() > 0.9 * len(df)]
unique_columns
# Out:
# DOL Vehicle ID    75215
# dtype: int64

# %% [markdown]
# Rows with missing values

# %%
df[df.isnull().any(axis=1)]
# Out:
#        VIN (1-10)     County             City State  Postal Code  Model Year  \
# 1      5YJ3E1EA7K  San Diego        San Diego    CA        92101        2019
# 2      7JRBR0FL9M       Lane           Eugene    OR        97404        2021
# 13     5YJSA1CG3D  Riverside            Indio    CA        92201        2013
# 14     1FADP3R48H       Kern         Rosamond    CA        93560        2017
# 53     5YJSA1H13E   Thurston          Olympia    WA        98502        2014
# ...           ...        ...              ...   ...          ...         ...
# 74402  7SAYGAEE0P    Stevens  Nine Mile Falls    WA        99026        2023
# 74468  1C4RJYE67N    Stevens        Deer Park    WA        99006        2022
# 74638  YV4ED3UL4P       King          Seattle    WA        98117        2023
# 74802  YV4ED3UL2P       King        Newcastle    WA        98056        2023
# 74960  5YJ3E1EBXJ  Snohomish       Marysville    WA        98271        2018
#
# ...

# %% [markdown]
# Rows where Legislative District is missing

# %%
df[df["Legislative District"].isnull()]
# Out:
#        VIN (1-10)      County        City State  Postal Code  Model Year  \
# 1      5YJ3E1EA7K   San Diego   San Diego    CA        92101        2019
# 2      7JRBR0FL9M        Lane      Eugene    OR        97404        2021
# 13     5YJSA1CG3D   Riverside       Indio    CA        92201        2013
# 14     1FADP3R48H        Kern    Rosamond    CA        93560        2017
# 106    3FA6P0SU9E   San Diego    Coronado    CA        92118        2014
# ...           ...         ...         ...   ...          ...         ...
# 66430  5YJ3E1EB2M   San Mateo   San Mateo    CA        94403        2021
# 66614  JTDKAMFP0M    Maricopa       Tempe    AZ        85281        2021
# 67860  1G1RA6S5XJ  Cumberland  Fort Bragg    NC        28307        2018
# 70566  KM8K33AG4N      Solano     Benicia    CA        94510        2022
# 74065  YV1BK0EP3N   San Diego   San Diego    CA        92111        2022
#
#             Make          Model                   Electric Vehicle Type  \
# ...
